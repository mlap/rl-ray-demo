# %%
#import sys
#!{sys.executable} -m pip install torch tensorflow "gym[atari]" "gym[accept-rom-license]" atari_py "ray[rllib, tune]"

# %%
import torch
torch.cuda.device_count()
# Out:
# 1

# %%
import argparse
import numpy as np

import ray
from ray.rllib.agents.ppo import PPOTrainer
from ray.rllib.examples.env.stateless_cartpole import StatelessCartPole
from ray.rllib.examples.models.trajectory_view_utilizing_models import \
    FrameStackingCartPoleModel, TorchFrameStackingCartPoleModel
from ray.rllib.models.catalog import ModelCatalog
from ray.rllib.utils.framework import try_import_tf
from ray.rllib.utils.test_utils import check_learning_achieved
from ray import tune
# Out:
# /home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):

# %%
tf1, tf, tfv = try_import_tf()

parser = argparse.ArgumentParser()
parser.add_argument(
    "--run",
    type=str,
    default="PPO",
    help="The RLlib-registered algorithm to use.")
parser.add_argument(
    "--framework",
    choices=["tf", "tf2", "tfe", "torch"],
    default="tf",
    help="The DL framework specifier.")
parser.add_argument(
    "--as-test",
    action="store_true",
    help="Whether this script should be run as a test: --stop-reward must "
    "be achieved within --stop-timesteps AND --stop-iters.")
parser.add_argument(
    "--stop-iters",
    type=int,
    default=50,
    help="Number of iterations to train.")
parser.add_argument(
    "--stop-timesteps",
    type=int,
    default=200000,
    help="Number of timesteps to train.")
parser.add_argument(
    "--stop-reward",
    type=float,
    default=150.0,
    help="Reward at which we stop training.")

if __name__ == "__main__":
    args = parser.parse_args()
    ray.init(num_cpus=3)

    num_frames = 16

    ModelCatalog.register_custom_model(
        "frame_stack_model", FrameStackingCartPoleModel
        if args.framework != "torch" else TorchFrameStackingCartPoleModel)

    config = {
        "env": StatelessCartPole,
        "model": {
            "vf_share_layers": True,
            "custom_model": "frame_stack_model",
            "custom_model_config": {
                "num_frames": num_frames,
            },

            # To compare against a simple LSTM:
            # "use_lstm": True,
            # "lstm_use_prev_action": True,
            # "lstm_use_prev_reward": True,

            # To compare against a simple attention net:
            # "use_attention": True,
            # "attention_use_n_prev_actions": 1,
            # "attention_use_n_prev_rewards": 1,
        },
        "num_sgd_iter": 5,
        "vf_loss_coeff": 0.0001,
        "framework": args.framework,
    }

    stop = {
        "training_iteration": args.stop_iters,
        "timesteps_total": args.stop_timesteps,
        "episode_reward_mean": args.stop_reward,
    }
    results = tune.run(
        args.run, config=config, stop=stop, verbose=2, checkpoint_at_end=True)

    if args.as_test:
        check_learning_achieved(results, args.stop_reward)

    checkpoints = results.get_trial_checkpoints_paths(
        trial=results.get_best_trial("episode_reward_mean", mode="max"),
        metric="episode_reward_mean")

    checkpoint_path = checkpoints[0][0]
    trainer = PPOTrainer(config)
    trainer.restore(checkpoint_path)

    # Inference loop.
    env = StatelessCartPole()

    # Run manual inference loop for n episodes.
    for _ in range(10):
        episode_reward = 0.0
        reward = 0.0
        action = 0
        done = False
        obs = env.reset()
        while not done:
            # Create a dummy action using the same observation n times,
            # as well as dummy prev-n-actions and prev-n-rewards.
            action, state, logits = trainer.compute_single_action(
                input_dict={
                    "obs": obs,
                    "prev_n_obs": np.stack([obs for _ in range(num_frames)]),
                    "prev_n_actions": np.stack([0 for _ in range(num_frames)]),
                    "prev_n_rewards": np.stack(
                        [1.0 for _ in range(num_frames)]),
                },
                full_fetch=True)
            obs, reward, done, info = env.step(action)
            episode_reward += reward

        print(f"Episode reward={episode_reward}")

    ray.shutdown()
# Out:
# usage: ipykernel_launcher.py [-h] [--run RUN] [--framework {tf,tf2,tfe,torch}]
#                              [--as-test] [--stop-iters STOP_ITERS]
#                              [--stop-timesteps STOP_TIMESTEPS]
#                              [--stop-reward STOP_REWARD]
# ipykernel_launcher.py: error: argument --framework: invalid choice: '/tmp/tmp-122929NzpImw5NCGWS.json' (choose from 'tf', 'tf2', 'tfe', 'torch')
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 1787, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 1993, in _parse_known_args
#     start_index = consume_optional(start_index)
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 1933, in consume_optional
#     take_action(action, args, option_string)
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 1845, in take_action
#     argument_values = self._get_values(action, argument_strings)
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 2377, in _get_values
#     self._check_value(action, value)
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 2433, in _check_value
#     raise ArgumentError(action, msg % args)
# argparse.ArgumentError: argument --framework: invalid choice: '/tmp/tmp-122929NzpImw5NCGWS.json' (choose from 'tf', 'tf2', 'tfe', 'torch')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_154445/1846671984.py", line 36, in <module>
#     args = parser.parse_args()
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 1755, in parse_args
#     args, argv = self.parse_known_args(args, namespace)
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 1794, in parse_known_args
#     self.error(str(err))
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 2508, in error
#     self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/argparse.py", line 2495, in exit
#     _sys.exit(status)
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/cboettig/.pyenv/versions/3.7.9/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in parse_known_args(self, args, namespace)
#    1786         try:
# -> 1787             namespace, args = self._parse_known_args(args, namespace)
#    1788             if hasattr(namespace, _UNRECOGNIZED_ARGS_ATTR):
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in _parse_known_args(self, arg_strings, namespace)
#    1992             # consume the next optional and any arguments for it
# -> 1993             start_index = consume_optional(start_index)
#    1994
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in consume_optional(start_index)
#    1932             for action, args, option_string in action_tuples:
# -> 1933                 take_action(action, args, option_string)
#    1934             return stop
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in take_action(action, argument_strings, option_string)
#    1844             seen_actions.add(action)
# -> 1845             argument_values = self._get_values(action, argument_strings)
#    1846
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in _get_values(self, action, arg_strings)
#    2376             value = self._get_value(action, arg_string)
# -> 2377             self._check_value(action, value)
#    2378
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in _check_value(self, action, value)
#    2432             msg = _('invalid choice: %(value)r (choose from %(choices)s)')
# -> 2433             raise ArgumentError(action, msg % args)
#    2434
#
# ArgumentError: argument --framework: invalid choice: '/tmp/tmp-122929NzpImw5NCGWS.json' (choose from 'tf', 'tf2', 'tfe', 'torch')
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_154445/1846671984.py in <module>
#      35 if __name__ == "__main__":
# ---> 36     args = parser.parse_args()
#      37     ray.init(num_cpus=3)
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in parse_args(self, args, namespace)
#    1754     def parse_args(self, args=None, namespace=None):
# -> 1755         args, argv = self.parse_known_args(args, namespace)
#    1756         if argv:
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in parse_known_args(self, args, namespace)
#    1793             err = _sys.exc_info()[1]
# -> 1794             self.error(str(err))
#    1795
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in error(self, message)
#    2507         args = {'prog': self.prog, 'message': message}
# -> 2508         self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/argparse.py in exit(self, status, message)
#    2494             self._print_message(message, _sys.stderr)
# -> 2495         _sys.exit(status)
#    2496
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2069                            'the full traceback.\n']
#    2070                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2071                                                                      value))
#    2072                 else:
#    2073                     try:
#
# ~/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# ~/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     631                     chained_exceptions_tb_offset, context)
#     632                 + chained_exception_message
# --> 633                 + out_list)
#     634
#     635         return out_list
#
# ~/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# ~/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# ~/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
