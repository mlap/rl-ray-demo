# %%
import sys
# !{sys.executable} -m pip install torch tensorflow "gym[atari]" "gym[accept-rom-license]" atari_py "ray[rllib, tune]"

# %%
import torch
torch.cuda.device_count()
# Out:
# 1

# %%
# Import the RL algorithm (Trainer) we would like to use.
from ray.rllib.agents.ppo import PPOTrainer

# Configure the algorithm.
config = {
    # Environment (RLlib understands openAI gym registered strings).
    "env": "Taxi-v3",
    # Use 2 environment workers (aka "rollout workers") that parallelly
    # collect samples from their own environment clone(s).
    "num_workers": 4,
    # Change this to "framework: torch", if you are using PyTorch.
    # Also, use "framework: tf2" for tf2.x eager execution.
    "framework": "torch",
    "num_gpus": 1,
    # Tweak the default model provided automatically by RLlib,
    # given the environment's observation- and action spaces.
    "model": {
        "fcnet_hiddens": [64, 64],
        "fcnet_activation": "relu",
    },
    # Set up a separate evaluation worker set for the
    # `trainer.evaluate()` call after training (see below).
    "evaluation_num_workers": 1,
    # Only for evaluation runs, render the env.
    "evaluation_config": {
        "render_env": True,
    }
}

# Create our RLlib Trainer.
trainer = PPOTrainer(config=config)

# Run it for n training iterations. A training iteration includes
# parallel sample collection by the environment workers as well as
# loss calculation on the collected batch and a model update.
for _ in range(3):
    print(trainer.train())

# Evaluate the trained Trainer (and render each timestep to the shell's
# output).
trainer.evaluate()
# Out:
# /home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# 2022-01-26 04:17:20,916	WARNING trainer.py:1948 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-01-26 04:17:22,300	WARNING services.py:1826 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67096576 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# (pid=16709) /home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
# (pid=16709)   for external in metadata.entry_points().get(self.group, []):
# (pid=16723) /home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
# (pid=16723)   for external in metadata.entry_points().get(self.group, []):
# (RolloutWorker pid=16723) 2022-01-26 04:17:29,494	WARNING deprecation.py:46 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# 2022-01-26 04:17:31,350	WARNING deprecation.py:46 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# 2022-01-26 04:17:32,649	WARNING deprecation.py:46 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# 2022-01-26 04:17:32,650	WARNING trainer.py:1948 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# (pid=16710) /home/cboettig/.local/share/virtualenvs/rl-ray-demo-y9hdSGSh/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
# (pid=16710)   for external in metadata.entry_points().get(self.group, []):
# (RolloutWorker pid=16710) 2022-01-26 04:17:38,323	WARNING deprecation.py:46 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# 2022-01-26 04:17:40,606	INFO trainable.py:127 -- Trainable.setup took 19.691 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-01-26 04:17:40,608	WARNING util.py:57 -- Install gputil for GPU system monitoring.
# 2022-01-26 04:17:43,929	WARNING deprecation.py:46 -- DeprecationWarning: `slice` has been deprecated. Use `SampleBatch[start:stop]` instead. This will raise an error in the future!
# {'episode_reward_max': -427.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -759.0, 'episode_len_mean': 196.65, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-758.0, -713.0, -803.0, -893.0, -668.0, -776.0, -830.0, -758.0, -758.0, -803.0, -722.0, -794.0, -427.0, -875.0, -758.0, -857.0, -830.0, -587.0, -875.0, -695.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 133, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.12141463162004203, 'mean_inference_ms': 1.2459100811913988, 'mean_action_processing_ms': 0.08091695424260525, 'mean_env_wait_ms': 0.07077040283874178, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 4000, 'timesteps_this_iter': 0, 'agent_timesteps_total': 4000, 'timers': {'sample_time_ms': 11280.457, 'sample_throughput': 354.596, 'load_time_ms': 0.585, 'load_throughput': 6842257.749, 'learn_time_ms': 4239.875, 'learn_throughput': 943.424, 'update_time_ms': 3.01}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.20000000298023224, 'cur_lr': 4.999999873689376e-05, 'total_loss': 47406.656, 'policy_loss': 0.009830529, 'vf_loss': 47406.645, 'vf_explained_var': -0.00012448001, 'kl': 0.0007873148, 'entropy': 1.7909595, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}}}, 'num_steps_sampled': 4000, 'num_agent_steps_sampled': 4000, 'num_steps_trained': 4000, 'num_agent_steps_trained': 4000}, 'done': False, 'episodes_total': 20, 'training_iteration': 1, 'trial_id': 'default', 'experiment_id': 'd9b249b665594d179cdd3cf6f8ad45f0', 'date': '2022-01-26_04-17-48', 'timestamp': 1643170668, 'time_this_iter_s': 7.57633376121521, 'time_total_s': 7.57633376121521, 'pid': 16396, 'hostname': 'f3c1977db4f9', 'node_ip': '172.18.0.5', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': 'Taxi-v3', 'observation_space': None, 'action_space': None, 'env_config': {}, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'env_task_fn': None, 'render_env': False, 'record_env': False, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, 'preprocessor_pref': 'deepmind', 'log_level': 'WARN', 'callbacks': <class 'ray.rllib.agents.callbacks.DefaultCallbacks'>, 'ignore_worker_failures': False, 'log_sys_usage': True, 'fake_sampler': False, 'framework': 'tf', 'eager_tracing': False, 'eager_max_retraces': 20, 'explore': True, 'exploration_config': {'type': 'StochasticSampling'}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'evaluation_parallel_to_training': False, 'in_evaluation' ...
# {'episode_reward_max': -427.0, 'episode_reward_min': -902.0, 'episode_reward_mean': -757.825, 'episode_len_mean': 198.325, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-758.0, -713.0, -803.0, -893.0, -668.0, -776.0, -830.0, -758.0, -758.0, -803.0, -722.0, -794.0, -427.0, -875.0, -758.0, -857.0, -830.0, -587.0, -875.0, -695.0, -686.0, -776.0, -722.0, -749.0, -902.0, -686.0, -758.0, -749.0, -785.0, -749.0, -704.0, -641.0, -839.0, -776.0, -830.0, -740.0, -713.0, -758.0, -767.0, -803.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 133, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.12119071569197651, 'mean_inference_ms': 1.2405627125521839, 'mean_action_processing_ms': 0.08086245615031093, 'mean_env_wait_ms': 0.0707110911545558, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 8000, 'timesteps_this_iter': 0, 'agent_timesteps_total': 8000, 'timers': {'sample_time_ms': 9399.418, 'sample_throughput': 425.558, 'load_time_ms': 0.625, 'load_throughput': 6401074.399, 'learn_time_ms': 4156.132, 'learn_throughput': 962.433, 'update_time_ms': 2.781}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.10000000149011612, 'cur_lr': 4.999999873689376e-05, 'total_loss': 39470.414, 'policy_loss': 0.0018887663, 'vf_loss': 39470.41, 'vf_explained_var': 0.00016104631, 'kl': 0.0059689325, 'entropy': 1.7727114, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}}}, 'num_steps_sampled': 8000, 'num_agent_steps_sampled': 8000, 'num_steps_trained': 8000, 'num_agent_steps_trained': 8000, 'num_steps_trained_this_iter': 0}, 'done': False, 'episodes_total': 40, 'training_iteration': 2, 'trial_id': 'default', 'experiment_id': 'd9b249b665594d179cdd3cf6f8ad45f0', 'date': '2022-01-26_04-17-55', 'timestamp': 1643170675, 'time_this_iter_s': 7.32952356338501, 'time_total_s': 14.90585732460022, 'pid': 16396, 'hostname': 'f3c1977db4f9', 'node_ip': '172.18.0.5', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': 'Taxi-v3', 'observation_space': None, 'action_space': None, 'env_config': {}, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'env_task_fn': None, 'render_env': False, 'record_env': False, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, 'preprocessor_pref': 'deepmind', 'log_level': 'WARN', 'callbacks': <class 'ray.rllib.agents.callbacks.DefaultCallbacks'>, 'ignore_worker_failures': False, 'log_sy ...
# {'episode_reward_max': -388.0, 'episode_reward_min': -902.0, 'episode_reward_mean': -720.8166666666667, 'episode_len_mean': 197.71666666666667, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-758.0, -713.0, -803.0, -893.0, -668.0, -776.0, -830.0, -758.0, -758.0, -803.0, -722.0, -794.0, -427.0, -875.0, -758.0, -857.0, -830.0, -587.0, -875.0, -695.0, -686.0, -776.0, -722.0, -749.0, -902.0, -686.0, -758.0, -749.0, -785.0, -749.0, -704.0, -641.0, -839.0, -776.0, -830.0, -740.0, -713.0, -758.0, -767.0, -803.0, -569.0, -677.0, -551.0, -587.0, -388.0, -758.0, -659.0, -677.0, -650.0, -659.0, -659.0, -641.0, -704.0, -668.0, -731.0, -650.0, -731.0, -632.0, -677.0, -668.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 133, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 130, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.12144080778607043, 'mean_inference_ms': 1.2389730145664224, 'mean_action_processing_ms': 0.08079792167983012, 'mean_env_wait_ms': 0.07067654001220765, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 12000, 'timesteps_this_iter': 0, 'agent_timesteps_total': 12000, 'timers': {'sample_time_ms': 8717.864, 'sample_throughput': 458.828, 'load_time_ms': 0.628, 'load_throughput': 6370288.318, 'learn_time_ms': 4040.712, 'learn_throughput': 989.925, 'update_time_ms': 2.796}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.10000000149011612, 'cur_lr': 4.999999873689376e-05, 'total_loss': 19462.566, 'policy_loss': -0.0066528777, 'vf_loss': 19462.572, 'vf_explained_var': -0.0002692811, 'kl': 0.010446359, 'entropy': 1.7280064, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}}}, 'num_steps_sampled': 12000, 'num_agent_steps_sampled': 12000, 'num_steps_trained': 12000, 'num_agent_steps_trained': 12000, 'num_steps_trained_this_iter': 0}, 'done': False, 'episodes_total': 60, 'training_iteration': 3, 'trial_id': 'default', 'experiment_id': 'd9b249b665594d179cdd3cf6f8ad45f0', 'date': '2022-01-26_04-18-02', 'timestamp': 1643170682, 'time_this_iter_s': 7.076249122619629, 'time_total_s': 21.98210644721985, 'pid': 16396, 'hostname': 'f3c1977db4f9', 'node_ip': '172.18.0.5', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': 'Taxi-v3', 'observation_space': None, 'action_space': None, 'env_config': {}, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'env_ta ...
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# ...
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) |_| : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Pickup)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (Dropoff)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (South)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (West)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (North)
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710) |R: | : :G|
# (RolloutWorker pid=16710) | : | : : |
# (RolloutWorker pid=16710) | : : : : |
# (RolloutWorker pid=16710) | | : | : |
# (RolloutWorker pid=16710) |Y| : |B: |
# (RolloutWorker pid=16710) +---------+
# (RolloutWorker pid=16710)   (East)
# {'evaluation': {'episode_reward_max': -470.0,
#   'episode_reward_min': -578.0,
#   'episode_reward_mean': -528.5,
#   'episode_len_mean': 200.0,
#   'episode_media': {},
#   'episodes_this_iter': 10,
#   'policy_reward_min': {},
#   'policy_reward_max': {},
#   'policy_reward_mean': {},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [-569.0,
#     -578.0,
#     -470.0,
#     -506.0,
#     -506.0,
#     -524.0,
#     -551.0,
#     -515.0,
#     -551.0,
#     -515.0],
#    'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200]},
#   'sampler_perf': {'mean_raw_obs_processing_ms': 0.12912480965785417,
#    'mean_inference_ms': 1.3407714839937206,
#    'mean_action_processing_ms': 0.0861973121486742,
#    'mean_env_wait_ms': 0.07715897224117432,
#    'mean_env_render_ms': 0.09610866201573286},
#   'off_policy_estimator': {}}}
